# %% [markdown]
# ### Continuação
#
# ##### Carregamento do dataset criado no ficheiro anterior:
#
# Tal como referido anteriormente, o dataset foi gravado num ficheiro csv, pelo que agora procedemos ao carregamento do mesmo.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
d=pd.read_csv('dados_bio.csv')
d
# Out:
#                    Drug_ID                                               Drug  \
# 0               Propanolol                   CC(C)NCC(O)COc1cccc2ccccc12.[Cl]
# 1     Terbutylchlorambucil             CC(C)(C)OC(=O)CCCc1ccc(N(CCCl)CCCl)cc1
# 2                    40730   CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 3                       24                     CC(=O)NCCCOc1cccc(CN2CCCCC2)c1
# 4              cloxacillin  Cc1onc(-c2ccccc2Cl)c1C(=O)N[C@@H]1C(=O)N2[C@@H...
# ...                    ...                                                ...
# 1971          rolziracetam                                 O=C1CCC2CCC(=O)N12
# 1972              ropizine      Cc1cccc(/C=N/N2CCN(C(c3ccccc3)c3ccccc3)CC2)n1
# 1973            rufinamide                       NC(=O)c1cn(Cc2c(F)cccc2F)nn1
# 1974            sabeluzole      CN(c1nc2ccccc2s1)C1CCN(CC(O)COc2ccc(F)cc2)CC1
# 1975           seproxetine                  NCCC(Oc1ccc(C(F)(F)F)cc1)c1ccccc1
#
# ...

# %% [markdown]
# #### Visualização dos Dados:
#
# Neste secção iremos procurar entender os dados, recorrendo a análises estatísticas e análises gráficas.
#
# Para uma melhor compreensão do dataset utilizamos o describe. Esta operação é útil para ter uma visão rápida e resumida do conjunto de dados, permitindo ver as características principais sem ter que examinar todas as informações detalhadamente.

# %%
# Análise estatística

pd.set_option('display.max_columns', None)
d.describe()
# Out:
#                 MW    Nº Atomos  Nº Ligações  Nº Eletrões Valência  \
# count  1976.000000  1976.000000  1976.000000           1976.000000
# mean    345.443688    46.555668    48.455466            108.448381
# std     151.906085    21.557293    22.582172             48.169105
# min      28.031300     5.000000     4.000000              8.000000
# 25%     257.060500    34.000000    35.000000             80.000000
# 50%     325.134677    44.000000    46.000000            106.000000
# 75%     412.131031    55.000000    58.000000            128.000000
# max    1877.556582   269.000000   281.000000            582.000000
#
#        Nº Eletrões Valência.1  Nº H Dadores  Nº H Aceitadores         Nº C  \
# count             1976.000000   1976.000000       1976.000000  1976.000000
# mean               108.448381      1.565283          4.609312    18.017206
# std                 48.169105      1.859574          3.267205     8.067921
# ...

# %% [markdown]
# #### Verificação de missing values:

# %%
#  número de missing values

print("\nValores ausentes no conjunto de dados:")
print(d.isnull().sum())
# Out:
# Valores ausentes no conjunto de dados:
# Drug_ID                      0
# Drug                         0
# MW                           0
# Nº Atomos                    0
# Nº Ligações                  0
# Nº Eletrões Valência         0
# Nº Eletrões Valência.1       0
# Nº H Dadores                 0
# Nº H Aceitadores             0
# Nº C                         0
# Nº N                         0
# Nº O                         0
# Nº Cl                        0
# Nº F                         0
# Nº S                         0
# Nº Br                        0
# Nº I                         0
# Nº H                         0
# Nº Na                        0
# Nº de ligações single        0
# Nº de ligações double        0
# Nº de ligações triple        0
# Nº de ligações aromatic      0
# Log(P)                       0
# Nº de Álcoois                0
# Nº de Cetonas                0
# Nº de Ésteres                0
# Nº de Aminas                 0
# Nº de Ácidos Carboxílicos    0
# ...

# %% [markdown]
# #### Verificação de valores únicos:
#
# Esta verificação teve como principal objetivo identificar possíveis valores duplicados no dataset.

# %%
unique_counts = d.nunique()
print("\nContagem de Valores Únicos:")
print(unique_counts)
# Out:
# Contagem de Valores Únicos:
# Drug_ID                      1964
# Drug                         1923
# MW                           1700
# Nº Atomos                     123
# Nº Ligações                   130
# Nº Eletrões Valência          133
# Nº Eletrões Valência.1        133
# Nº H Dadores                   17
# Nº H Aceitadores               26
# Nº C                           57
# Nº N                           14
# Nº O                           24
# Nº Cl                           7
# Nº F                            9
# Nº S                            5
# Nº Br                           4
# Nº I                            4
# Nº H                            4
# Nº Na                           4
# Nº de ligações single          71
# Nº de ligações double          14
# Nº de ligações triple           3
# Nº de ligações aromatic        23
# Log(P)                       1866
# Nº de Álcoois                  12
# Nº de Cetonas                   5
# ...

# %% [markdown]
# Após a verificação anterior percebemos que o nº de Drugs não corresponde ao valor de instâncias, demonstrado que poderá existir Drugs repetidas. Assim, realiza-se a vericação dos duplicados na coluna.

# %%
def verificarDuplicados(dataset, coluna):
    duplicados = dataset[coluna].duplicated(keep=False)
    return dataset[duplicados]


contadorDuplicados = d['Drug'].duplicated(keep=False).sum()
print(f"Número de duplicados em 'Drug': {contadorDuplicados}")
# Out:
# Número de duplicados em 'Drug': 103

# %% [markdown]
# #### Gráficos Exploratórios:
#
# #### Matriz Correlação:

# %%
import seaborn as sns
import matplotlib.pyplot as plt


numeric_columns = d.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = d[numeric_columns].corr()


plt.figure(figsize=(22, 17))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Matriz de Correlação")
plt.show()

# %% [markdown]
# #### Frequência das diversas ligações:

# %%
import matplotlib.pyplot as plt
import numpy as np

categorias = ['']

vars_col1 = d['Nº de ligações single'].sum()
vars_col2 = d['Nº de ligações double'].sum()
vars_col3 = d['Nº de ligações triple'].sum()
vars_col4 = d['Nº de ligações aromatic'].sum()

largura_barra = 0.25

pos_col1 = np.arange(len(categorias))
pos_col2 = [x + largura_barra for x in pos_col1]
pos_col3 = [x + largura_barra for x in pos_col2]
pos_col4 = [x + largura_barra for x in pos_col3]

plt.bar(pos_col1, vars_col1, largura_barra, label='Ligações simples', color='red')
plt.bar(pos_col2, vars_col2, largura_barra, label='Ligações duplas', color='green')
plt.bar(pos_col3, vars_col3, largura_barra, label='Ligações triplas', color='blue')
plt.bar(pos_col4, vars_col4, largura_barra, label='Ligações aromáticas', color='yellow') 

plt.xlabel('Tipo de ligações')
plt.ylabel('Frequência absoluta')
plt.title('Nº dos vários tipos de ligações:')
plt.xticks([x + largura_barra for x in pos_col1], categorias)
plt.legend()

plt.show()
print()

# %% [markdown]
# #### Percentagem dos diversos Grupos Funcionais presentes:

# %%
import matplotlib.pyplot as plt

alcoois = d['Nº de Álcoois']
cetonas = d['Nº de Cetonas']
esteres = d['Nº de Ésteres']
aminas = d['Nº de Aminas']
acidos = d['Nº de Ácidos Carboxílicos']
eteres = d['Nº de Éteres']

total_alcoois = alcoois.sum()
total_cetonas = cetonas.sum()
total_esteres = esteres.sum()
total_aminas = aminas.sum()
total_acidos = acidos.sum()
total_eteres = eteres.sum()
total_= total_alcoois+total_cetonas+total_esteres+total_aminas+total_acidos+total_eteres

percentagem_alcoois = [total_alcoois / total_* 100]
percentagem_cetonas = [total_cetonas / total_ * 100]
percentagem_esteres = [total_esteres / total_ * 100]
percentagem_aminas = [total_aminas / total_ * 100]
percentagem_acidos = [total_acidos / total_ * 100]
percentagem_eteres = [total_eteres / total_ * 100]
 
labels = ['Álcoois', 'Cetonas', 'Ésteres','Aminas','Ácidos Carboxílicos','Éteres']
sizes = [sum(percentagem_alcoois), sum(percentagem_cetonas), sum(percentagem_esteres),sum(percentagem_aminas),sum(percentagem_acidos),sum(percentagem_eteres)]

textprops = {'color': 'black'}

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=45, colors=['orange', 'grey', 'red', 'green', 'coral', 'blue'], textprops=textprops)

plt.title('Percentagem de Grupos Funcionais:', color='black')

plt.show()

# %% [markdown]
# #### Tratamento de Dados
#
# #### Tratamento dos missing values utilizando o valor médio:

# %%
print(d.isna().sum().sum())

for coluna in d.columns[3:]:
    d[coluna] = d[coluna].fillna(d[coluna].mean())
# Out:
# 4

# %%
valores_ausentes = d.isnull().sum()

print(valores_ausentes)
# Out:
# Drug_ID                      0
# Drug                         0
# MW                           0
# Nº Atomos                    0
# Nº Ligações                  0
# Nº Eletrões Valência         0
# Nº Eletrões Valência.1       0
# Nº H Dadores                 0
# Nº H Aceitadores             0
# Nº C                         0
# Nº N                         0
# Nº O                         0
# Nº Cl                        0
# Nº F                         0
# Nº S                         0
# Nº Br                        0
# Nº I                         0
# Nº H                         0
# Nº Na                        0
# Nº de ligações single        0
# Nº de ligações double        0
# Nº de ligações triple        0
# Nº de ligações aromatic      0
# Log(P)                       0
# Nº de Álcoois                0
# Nº de Cetonas                0
# Nº de Ésteres                0
# Nº de Aminas                 0
# Nº de Ácidos Carboxílicos    0
# Nº de Éteres                 0
# ...

# %% [markdown]
# #### Tratamento dos valores duplicados:

# %%
# Remover duplicados na coluna 'Drug', mantendo a primeira ocorrência
d = d.drop_duplicates(subset=['Drug'], keep='first')

# Verificação do número de valores únicos após a remoção dos duplicados
unique_counts = d.nunique()
print("\nContagem de Valores Únicos após a remoção de duplicatas:")
print(unique_counts)

len(d)
# Out:
# Contagem de Valores Únicos após a remoção de duplicatas:
# Drug_ID                      1914
# Drug                         1923
# MW                           1700
# Nº Atomos                     123
# Nº Ligações                   130
# Nº Eletrões Valência          133
# Nº Eletrões Valência.1        133
# Nº H Dadores                   17
# Nº H Aceitadores               26
# Nº C                           57
# Nº N                           14
# Nº O                           24
# Nº Cl                           7
# Nº F                            9
# Nº S                            5
# Nº Br                           4
# Nº I                            4
# Nº H                            4
# Nº Na                           4
# Nº de ligações single          71
# Nº de ligações double          14
# Nº de ligações triple           3
# Nº de ligações aromatic        23
# Log(P)                       1866
# Nº de Álcoois                  12
# Nº de Cetonas                   5
# ...

# %% [markdown]
# ### Secção 2 : Redução de Dimensionalidade
#
# #### Técnicas para redução de dimensionalidade:
#
# A redução de dimensionalidade é crucial na aplicação de modelos de Aprendizagem Automática. Em datasets de grandes dimensões, a diminuição do número de features não apenas melhora o desempenho dos modelos, tornando-os mais práticos, mas também reduz a necessidade de recursos computacionais significativos.
#
# Além disso, é vital evitar o overfitting, um fenômeno em que o modelo funciona bem com dados de treino, mas falha com dados inéditos. Ao reduzir a dimensão e complexidade do modelo, concentramo-nos nas features mais informativas, mitigando o risco de overfitting.
#
# A visualização e interpretabilidade do modelo também são beneficiadas pela redução de dimensionalidade. A projeção dos dados em espaços de menor dimensão facilita a identificação de padrões e relações entre as features do modelo e suas previsões.
#
# Assim, a redução de dimensionalidade visa encontrar o menor conjunto de variáveis capazes de descrever a máxima variabilidade dos dados, diminuindo a quantidade de dados a serem avaliados.

# %% [markdown]
# #### Normalização dos Dados:
#
# A normalização não é uma técnica de diminuição de dimensionalidade. No entanto, é um processo que ajusta as escalas dos dados, sendo aplicado a características numéricas. Dado que o dataset apresenta-se com diversas variáveis desta categoria, a normalização é um processo extremamente importante.

# %%
#Retirar Atributos não tão significativos e atributos que não se encontram no formato float, nomeadamente o Drug_ID, Drug e a nossa label "Y"
from sklearn.preprocessing import MinMaxScaler

pd.set_option('display.max_row', 10)

atributos=d.iloc[:, 2:-1]
atributos


scaler = MinMaxScaler(feature_range=(-1, 1))
atributos= pd.DataFrame(scaler.fit_transform(atributos), columns=atributos.columns)
atributos
# Out:
#             MW  Nº Atomos  Nº Ligações  Nº Eletrões Valência  \
# 0    -0.712256  -0.727273    -0.732852             -0.707317
# 1    -0.641951  -0.659091    -0.667870             -0.651568
# 2    -0.639786  -0.689394    -0.675090             -0.644599
# 3    -0.716502  -0.681818    -0.682310             -0.665505
# 4    -0.559850  -0.681818    -0.667870             -0.623693
# ...        ...        ...          ...                   ...
# 1918 -0.879935  -0.893939    -0.884477             -0.874564
# 1919 -0.629976  -0.628788    -0.617329             -0.560976
# 1920 -0.772877  -0.848485    -0.841155             -0.804878
# 1921 -0.581361  -0.621212    -0.610108             -0.574913
# 1922 -0.711183  -0.757576    -0.754513             -0.721254
#
#       Nº Eletrões Valência.1  Nº H Dadores  Nº H Aceitadores      Nº C  \
# 0                  -0.707317     -0.833333         -0.818182 -0.680851
# 1                  -0.651568     -1.000000         -0.818182 -0.638298
# ...

# %% [markdown]
# ##### VarianceThreshold:
#
# O objetivo passa por identificar as features que têm pouca ou nenhuma variação, pois não contribuem significativamente para a modelação. Se uma feature tem baixa variação, significa que os seus valores são relativamente constantes em todo o conjunto de dados, o que indica que ela não fornece muita informação útil para distinguir entre diferentes amostras.

# %%
threshold = 0.01

from sklearn.feature_selection import VarianceThreshold

var_threshold = VarianceThreshold(threshold=threshold)
x_variance = var_threshold.fit_transform(atributos)

variance_columns = atributos.columns[var_threshold.get_support()]


high_variance_data = atributos[variance_columns]
print("Features com maior variância:\n", high_variance_data.shape)
high_variance_data.head()
# Out:
# Features com maior variância:
#  (1923, 32)
#          MW  Nº Atomos  Nº Ligações  Nº Eletrões Valência  \
# 0 -0.712256  -0.727273    -0.732852             -0.707317
# 1 -0.641951  -0.659091    -0.667870             -0.651568
# 2 -0.639786  -0.689394    -0.675090             -0.644599
# 3 -0.716502  -0.681818    -0.682310             -0.665505
# 4 -0.559850  -0.681818    -0.667870             -0.623693
#
#    Nº Eletrões Valência.1  Nº H Dadores  Nº H Aceitadores      Nº C      Nº N  \
# 0               -0.707317     -0.833333         -0.818182 -0.680851 -0.882353
# 1               -0.651568     -1.000000         -0.818182 -0.638298 -0.882353
# 2               -0.644599     -0.916667         -0.636364 -0.638298 -0.647059
# 3               -0.665505     -0.916667         -0.818182 -0.659574 -0.764706
# 4               -0.623693     -0.833333         -0.636364 -0.617021 -0.647059
#
#        Nº O     Nº Cl      Nº F  Nº S  Nº Br  Nº H  Nº de ligações single  \
# ...

# %% [markdown]
# #### Seleção de dados por percentil:
#
# Refere-se a um método no qual os valores de uma variável são escolhidos com base na sua posição percentual em relação ao conjunto total de dados.
#
# Esta abordagem é útil em várias situações,nomeadamente, a remoção de valores extremos (outliers) ou a concentração numa faixa específica de valores.

# %%
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectPercentile, f_regression

selector = SelectPercentile(f_regression, percentile=50)

selector.fit(atributos, d["Y"])

selected_features = selector.transform(atributos)

df_percent = pd.DataFrame(selected_features, columns=atributos.columns[selector.get_support()])

df_percent
# Out:
#             MW  Nº Atomos  Nº Ligações  Nº Eletrões Valência  \
# 0    -0.712256  -0.727273    -0.732852             -0.707317
# 1    -0.641951  -0.659091    -0.667870             -0.651568
# 2    -0.639786  -0.689394    -0.675090             -0.644599
# 3    -0.716502  -0.681818    -0.682310             -0.665505
# 4    -0.559850  -0.681818    -0.667870             -0.623693
# ...        ...        ...          ...                   ...
# 1918 -0.879935  -0.893939    -0.884477             -0.874564
# 1919 -0.629976  -0.628788    -0.617329             -0.560976
# 1920 -0.772877  -0.848485    -0.841155             -0.804878
# 1921 -0.581361  -0.621212    -0.610108             -0.574913
# 1922 -0.711183  -0.757576    -0.754513             -0.721254
#
#       Nº Eletrões Valência.1  Nº H Dadores  Nº H Aceitadores      Nº N  \
# 0                  -0.707317     -0.833333         -0.818182 -0.882353
# 1                  -0.651568     -1.000000         -0.818182 -0.882353
# ...

# %%
import matplotlib.pyplot as plt

feature_scores = selector.scores_

feature_names = atributos.columns

plt.figure(figsize=(10, 6))
plt.bar(feature_names, feature_scores)
plt.xlabel('Características')
plt.ylabel('Pontuação F-regressão')
plt.title('Pontuação F-regressão das Características')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### SelectKBest:
#
# O SelectKBest é uma estratégia de filtragem que escolhe os k melhores recursos (ou colunas) de um conjunto de dados, visando reter apenas os mais relevantes. Esta técnica avalia cada recurso individualmente mediante uma métrica escolhida (F-value) e, em seguida, seleciona os k recursos com a pontuação mais elevada.

# %%
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd

labels = d['Y']
features = d.drop(['Y', 'Drug_ID', 'Drug'], axis=1)  

skb = SelectKBest(f_classif, k=10)
x_kbest = skb.fit_transform(features, labels)

selected_indices = skb.get_support(indices=True)

selected_columns = features.columns[selected_indices]

data_kbest = pd.DataFrame(data=x_kbest, index=features.index, columns=selected_columns)

# %%
import matplotlib.pyplot as plt

# Criar o boxplot dos dados selecionados com os 10 melhores amostras
plt.boxplot(data_kbest)
plt.title('10 melhores amostras')
plt.xticks(np.arange(1, 11), data_kbest.columns, rotation=90)
plt.show()

# %% [markdown]
# #### PCA - Principal Component Analysis:
#
# A Análise de Componente Principais (PCA) é uma técnica de redução de dimensionalidade, tendo como objetivo  a transformação de um dataset extenso e complexo num novo sistema de coordenadas (componentes principais), atendendo a que a variância dos dados é maximizada. O PCA assume relações lineares entre features, o que lhe confere também a capacidade de estabelecer combinações de features através destas relações, de tal modo a representar os dados de forma mais informativa.
#
# Assim, a aplicação da técnica de PCA permite captar as informações (features) de maior relevância à medida que reduz a dimensão dos dados. Com isto, consegue-se uma representação de dados computacionalmente mais eficientes e proporciona-se uma visualização facilitada dos dados de elevada dimensão para uma melhor análise e interpretação.

# %%
from sklearn.decomposition import PCA


n = 20
pca = PCA(n_components=n)
pca.fit(atributos)
x_pca = pca.transform(atributos)
x_pca=pd.DataFrame(x_pca)
x_pca
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.037685 -0.652426 -0.193034  0.056203  0.287871  0.319159 -0.332060
# 1     0.051593 -0.697170 -0.316336 -0.401065 -0.166913 -0.226675  0.122595
# 2     0.247631 -0.313306  0.056993  0.106924 -0.179832  0.415859  0.414907
# 3     0.025137 -0.669848 -0.218071 -0.238038 -0.070983  0.020930 -0.041894
# 4     0.391507 -0.093530  0.244129  0.380914 -0.414133  0.282755  0.187711
# ...        ...       ...       ...       ...       ...       ...       ...
# 1918 -0.810233  0.160508  0.197852 -0.223496 -0.148216  0.032757 -0.017349
# 1919  0.276517 -0.478023 -0.563582  0.305546  0.117550  0.020803  0.055232
# 1920 -0.455470 -0.219944 -0.020163  0.072220  0.053098  0.021282  0.068026
# 1921  0.544527 -0.775329 -0.358828  0.335025 -0.094703 -0.078064 -0.185488
# 1922 -0.244891 -0.447049 -0.198334 -0.034407  0.225029  0.038623 -0.104278
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(range(n), pca.explained_variance_ratio_*100)
plt.xticks(range(n), ['PC'+str(i) for i in range(1,n+1)])
plt.title("Variância Representada por PC")
plt.ylabel("Percentagem")

plt.show()

# %% [markdown]
# Através do gráfico demonstrando acima, resultante da análise PCA, entende-se que as features apresentam baixa capacidade de representar a variância dos dados, uma vez que tem-se um máximo de representação de variância pouco acima dos 25%, o que indica a necessidade de avaliar um conjunto mais extenso de PCs para representar corretamente os dados do caso.

# %%
# Verificação do número de PCA's que cobrem 90% da variância

pca90 = PCA(n_components=0.9)
pca90.fit(atributos)
x_reduced = pca90.transform(atributos)
totalPca = x_reduced.shape[1]

print( "Total PCA's:",totalPca )

# Tabela com o total de PCA's após a filtração

xPca=x_pca.loc[:, :12]
xPca
# Out:
# Total PCA's: 13
#             0         1         2         3         4         5         6   \
# 0     0.037685 -0.652426 -0.193034  0.056203  0.287871  0.319159 -0.332060
# 1     0.051593 -0.697170 -0.316336 -0.401065 -0.166913 -0.226675  0.122595
# 2     0.247631 -0.313306  0.056993  0.106924 -0.179832  0.415859  0.414907
# 3     0.025137 -0.669848 -0.218071 -0.238038 -0.070983  0.020930 -0.041894
# 4     0.391507 -0.093530  0.244129  0.380914 -0.414133  0.282755  0.187711
# 5     1.443234 -0.128976  0.722283  0.591105 -0.525726 -0.042646  0.103549
# 6     0.872713  0.400619  0.266575 -0.314472  0.374650  0.090199  0.017252
# 7    -0.162135 -0.076819 -0.347333  0.284168  0.098211  0.036798  0.090677
# 8     0.136219  0.149684 -0.105162  0.234673 -0.236472 -0.342779 -0.018742
# 9    -0.320489 -0.528033  1.053062  0.051830  1.196154 -0.397653  0.120516
# 10    0.371178 -0.654239 -0.213673  0.086415  0.211132  0.046779  0.188710
# ...

# %% [markdown]
# ### Secção 3 : Modelos de Aprendizagem
#
# #### Aprendizagem Supervisionada
#
# A abordagem da aprendizagem supervisionada no contexto do nosso estudo envolve treinar modelos utilizando um conjunto de dados em que as entradas estão associadas às saídas correspondentes. No nosso caso, o modelo é treinado com base nas informações das fórmulas químicas de fármacos, procurando perceber a sua relação com a penetração da BBB. O conjunto de dados inclui características dos fármacos e a variável target, que indica se um fármaco penetrou a barreira (1) ou não (0). Este é um problema de classificação supervisionada, pois estamos interessados em prever a resposta ao tratamento com base nos dados de expressão genética.
#
# Durante o treinamento do modelo, o algoritmo utiliza exemplos passados, onde a resposta ao tratamento é conhecida, para aprender a relação entre as características e o sucesso na penetração da barreira. Posteriormente, o modelo é capaz de generalizar esse conhecimento para prever a resposta para novos fármacos com base nas suas características. Portanto, neste contexto, iremos recorrer a modelos de aprendizagem supervisionada, dado que a variável target é discreta, indicando a sua natureza binária.
#
# Para a realização deste projeto, iremos realizar dois processos que serão dividos utilizando dois métodos diferentes (Split Data e Cross-Validation) e, posteriormente, aplicados a 5 modelos diferentes, sendo eles, Logistic Regression, Decision Tree, Random Forest, Naive Bayes e SVC-Support Vector Classification.
#
# Os dois processos são:
#
# - Processo 1 : Dataset inicial normalizado;
# - Processo 2 : Dataset proveniente do PCA;

# %% [markdown]
# #### Partição dos dados: Dados de treino / Dados de teste
#
# Antes da etapa de modelação, é necessário efetuar a partição de dados, essencial para avaliar e validar o desempenho dos modelos de machine learning. Efetuou-se, então, uma divisão de dados em conjuntos de treino e teste, segundo uma partição de 70% para dados de treino e, consequentemente, 30% para dados de teste, utilizados posteriormente para avaliar, de forma imparcial, o modelo final

# %% [markdown]
# #### Divisão dos dados Processo 1 usando Split Data:

# %%
from sklearn.model_selection import train_test_split

X_train_norm, X_test_norm, y_train_norm, y_test_norm = train_test_split(atributos, d["Y"], test_size=0.3, random_state=42)

print("Dimensões do conjunto de treino:", X_train_norm.shape, y_train_norm.shape)
print("Dimensões do conjunto de teste:", X_test_norm.shape, y_test_norm.shape)
# Out:
# Dimensões do conjunto de treino: (1346, 36) (1346,)
# Dimensões do conjunto de teste: (577, 36) (577,)

# %% [markdown]
# #### Divisão dos dados Processo 2 usando Split Data:

# %%
X_train, X_test, y_train, y_test = train_test_split(xPca, d["Y"], test_size=0.3)

print("Dimensões do conjunto de treino:", X_train.shape, y_train.shape)
print("Dimensões do conjunto de teste:", X_test.shape, y_test.shape)
# Out:
# Dimensões do conjunto de treino: (1346, 13) (1346,)
# Dimensões do conjunto de teste: (577, 13) (577,)

# %% [markdown]
# #### Aplicação de Modelos Supervisionados ao Processo 1:
#
# Para posterior avaliação dos modelos, que consiste num processo que mede o desempenho e eficácia dos algoritmos aplicados a dados de teste, ou seja, a dados não vistos durante o processo de treino, serão calculadas para todos os modelos aplicados a ambos os processos diversas métricas de avaliação.
#
# Matriz de Confusão: Tabela que compara as previsões do modelo com os valores reais do conjunto de teste, apresentando o número de verdadeiros positivos (TP), verdadeiros negativos (TN), falsos positivos (FP) e falsos negativos (FN). A partir desta é possível determinar:
#
#   - Accuracy: Proporção de previsões corretas em relação ao total de previões;
#
#   - Precision: Razão entre os verdadeiros positivos e o total de instâncias previstas como positivas;
#
#   - Recall(Sensibilidade): Proporção entre os verdadeiros positivos e o total de instâncias positivas no conjunto de dados.
#
#   - F1-Score: Combina precisão e recall num único valor de avaliação dos modelos. É utilizada em problemas de classificação desbalanceados, onde uma classe apresenta mais prevalência do que a outra e é particularmente útil em situações em que tanto falsos positivos quanto falsos negativos são importantes.

# %% [markdown]
# #### Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from prettytable import PrettyTable


RL_norm = LogisticRegression(max_iter=1000)

RL_norm.fit(X_train_norm, y_train_norm)

previsoes_norm = RL_norm.predict(X_test_norm)

relatorioRL_norm = classification_report(y_test_norm, previsoes_norm, output_dict=True)
matrix_confusao_RL_norm= confusion_matrix(y_test_norm, previsoes_norm)

linha_relatorioRL_norm = {
    'Modelo': 'Regressão Logística',
    'Accuracy': relatorioRL_norm['accuracy'],
    'Precision': relatorioRL_norm['1']['precision'],
    'Recall': relatorioRL_norm['1']['recall'],
    'F1-Score': relatorioRL_norm['1']['f1-score']
}

tabelaRL_norm = PrettyTable()
tabelaRL_norm.field_names = linha_relatorioRL_norm.keys()
tabelaRL_norm.add_row(linha_relatorioRL_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_RL_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Regressão Logística')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação:")
print(tabelaRL_norm)
# Out:
# Relatório de Classificação:
# +---------------------+--------------------+-------------------+-------------------+--------------------+
# |        Modelo       |      Accuracy      |     Precision     |       Recall      |      F1-Score      |
# +---------------------+--------------------+-------------------+-------------------+--------------------+
# | Regressão Logística | 0.8405545927209706 | 0.847870182555781 | 0.960919540229885 | 0.9008620689655172 |
# +---------------------+--------------------+-------------------+-------------------+--------------------+

# %% [markdown]
# #### Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier


treeclassifier_RL_norm = DecisionTreeClassifier()

treeclassifier_RL_norm.fit(X_train_norm, y_train_norm)

previsoes_tree_RL_norm = treeclassifier_RL_norm.predict(X_test_norm)

relatorio_tree_RL = classification_report(y_test_norm, previsoes_tree_RL_norm, output_dict=True)
matrix_confusao_tree_RL = confusion_matrix(y_test_norm, previsoes_tree_RL_norm)

linharelatorio_tree_RL_norm = {
    'Modelo': 'Regressão Logística',
    'Accuracy': relatorio_tree_RL['accuracy'],
    'Precision': relatorio_tree_RL['1']['precision'],
    'Recall': relatorio_tree_RL['1']['recall'],
    'F1-Score': relatorio_tree_RL['1']['f1-score']
}

tabelaTree_RL_norm = PrettyTable()
tabelaTree_RL_norm.field_names = linharelatorio_tree_RL_norm.keys()
tabelaTree_RL_norm.add_row(linharelatorio_tree_RL_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_tree_RL, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Árvore de Decisão')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Random Forest:")
print(tabelaTree_RL_norm)
# Out:
# Relatório de Classificação - Random Forest:
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# |        Modelo       |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# | Regressão Logística | 0.8214904679376083 | 0.8755656108597285 | 0.8896551724137931 | 0.8825541619156214 |
# +---------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier

RFC_norm = RandomForestClassifier()

RFC_norm.fit(X_train_norm, y_train_norm)

RFP_norm = RFC_norm.predict(X_test_norm)

relatorio_forest_norm = classification_report(y_test_norm, RFP_norm, output_dict=True)
matrix_confusaoRF_norm = confusion_matrix(y_test_norm, RFP_norm)

linha_relatorioRF_norm = {
    'Modelo': 'Random Forest',
    'Accuracy': relatorio_forest_norm['accuracy'],
    'Precision': relatorio_forest_norm['1']['precision'],
    'Recall': relatorio_forest_norm['1']['recall'],
    'F1-Score': relatorio_forest_norm['1']['f1-score']
}

tabelaRF_norm = PrettyTable()
tabelaRF_norm.field_names = linha_relatorioRF_norm.keys()
tabelaRF_norm.add_row(linha_relatorioRF_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusaoRF_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Random Forest')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Random Forest:")
print(tabelaRF_norm)
# Out:
# Relatório de Classificação - Random Forest:
# +---------------+-------------------+--------------------+--------------------+--------------------+
# |     Modelo    |      Accuracy     |     Precision      |       Recall       |      F1-Score      |
# +---------------+-------------------+--------------------+--------------------+--------------------+
# | Random Forest | 0.854419410745234 | 0.8726114649681529 | 0.9448275862068966 | 0.9072847682119206 |
# +---------------+-------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Naive Bayes:

# %%
from sklearn.naive_bayes import GaussianNB

NB_norm = GaussianNB()


NB_norm.fit(X_train_norm, y_train_norm)

previsoes_NB_norm = NB_norm.predict(X_test_norm)

relatorio_NB_norm = classification_report(y_test_norm, previsoes_NB_norm, output_dict=True)
matrixconfusao_NB_norm = confusion_matrix(y_test_norm, previsoes_NB_norm)

linharelatorio_NB_norm = {
    'Modelo': 'Naive Bayes',
    'Accuracy': relatorio_NB_norm['accuracy'],
    'Precision': relatorio_NB_norm['1']['precision'],
    'Recall': relatorio_NB_norm['1']['recall'],
    'F1-Score': relatorio_NB_norm['1']['f1-score']
}

tabelaNB_norm = PrettyTable()
tabelaNB_norm.field_names = linharelatorio_NB_norm.keys()
tabelaNB_norm.add_row(linharelatorio_NB_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrixconfusao_NB_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Naive Bayes')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Naive Bayes:")
print(tabelaNB_norm)
# Out:
# Relatório de Classificação - Naive Bayes:
# +-------------+--------------------+--------------------+-------------------+--------------------+
# |    Modelo   |      Accuracy      |     Precision      |       Recall      |      F1-Score      |
# +-------------+--------------------+--------------------+-------------------+--------------------+
# | Naive Bayes | 0.8180242634315424 | 0.8618421052631579 | 0.903448275862069 | 0.8821548821548822 |
# +-------------+--------------------+--------------------+-------------------+--------------------+

# %% [markdown]
# #### SVC - Support Vector Classification:

# %%
from sklearn.svm import SVC

SVC_norm = SVC(probability=True)

SVC_norm.fit(X_train_norm, y_train_norm)

previsoes_SVC_norm = SVC_norm.predict(X_test_norm)

relatorio_SVC_norm = classification_report(y_test_norm, previsoes_SVC_norm, output_dict=True)
matrixconfusao_SVC_norm = confusion_matrix(y_test_norm, previsoes_SVC_norm)

linharelatorio_SVC_norm = {
    'Modelo': 'SVM',
    'Accuracy': relatorio_SVC_norm['accuracy'],
    'Precision': relatorio_SVC_norm['1']['precision'],
    'Recall': relatorio_SVC_norm['1']['recall'],
    'F1-Score': relatorio_SVC_norm['1']['f1-score']
}

tabelaSVC_norm = PrettyTable()
tabelaSVC_norm.field_names = linharelatorio_SVC_norm.keys()
tabelaSVC_norm.add_row(linharelatorio_SVC_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrixconfusao_SVC_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - SVM')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - SVM:")
print(tabelaSVC_norm)
# Out:
# Relatório de Classificação - SVM:
# +--------+--------------------+--------------------+--------------------+--------------------+
# | Modelo |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +--------+--------------------+--------------------+--------------------+--------------------+
# |  SVM   | 0.8318890814558059 | 0.8421052631578947 | 0.9563218390804598 | 0.8955866523143164 |
# +--------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Aplicação de Modelos Supervisionados ao Processo 1, com a particição de dados através do Cross-Validation:
#
# O cross-validation, é uma técnica utilizada em machine learning para avaliar o desempenho de um modelo. O objetivo é maximizar a utilização dos dados disponíveis, principalmente em casos em que o conjunto de dados é limitado.
#
# Esta envolve a divisão do conjunto de dados em partes, chamadas "folds". O modelo é treinado em várias iterações, onde em cada iteração, um dos folds é utilizado como conjunto de teste, enquanto os folds restantes são usados como conjunto de treino. Esse processo é repetido até que todos os folds tenham sido utilizados como conjunto de teste. Para os processos utilizou-se um número de folds k=5. A validação cruzada é crucial para estimar a performance de um modelo de forma mais confiável, especialmente quando o conjunto de dados é limitado, evitando problemas como overfitting ou subestimação do desempenho do modelo.
#
# Segue-se o mesmo raciocínio aplicado ao processo, sendo calculadas as mesmas métricas para todos os modelos.

# %% [markdown]
# #### Logistic Regression:

# %%
from sklearn.model_selection import cross_val_predict

modeloRL_norm = LogisticRegression(max_iter=1000)
modeloRL_norm.fit(X_train, y_train)

previsoesCV_RLnorm = cross_val_predict(modeloRL_norm, atributos, d["Y"], cv=5)

relatorioCV_RLnorm = classification_report(d["Y"], previsoesCV_RLnorm, output_dict=True)
matrix_confusaoCV_RLnorm = confusion_matrix(d["Y"], previsoesCV_RLnorm)

linha_relatorioCV_RLnorm = {
    'Modelo': 'Regressão Logística',
    'Accuracy': relatorioCV_RLnorm['accuracy'],
    'Precision': relatorioCV_RLnorm['1']['precision'],
    'Recall': relatorioCV_RLnorm['1']['recall'],
    'F1-Score': relatorioCV_RLnorm['1']['f1-score']
}

tabelaCV_RLnorm = PrettyTable()
tabelaCV_RLnorm.field_names = linha_relatorioCV_RLnorm.keys()
tabelaCV_RLnorm.add_row(linha_relatorioCV_RLnorm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusaoCV_RLnorm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Regressão Logística')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação:")
print(tabelaCV_RLnorm)
# Out:
# Relatório de Classificação:
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# |        Modelo       |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# | Regressão Logística | 0.8424336973478939 | 0.8554590570719603 | 0.9516908212560387 | 0.9010127409343351 |
# +---------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Decision Tree:

# %%
TR_CV_norm = DecisionTreeClassifier()

TR_CV_norm = cross_val_predict(TR_CV_norm, atributos, d["Y"], cv=5)

relatorioTR_norm = classification_report(d["Y"], TR_CV_norm, output_dict=True)
matrixconfusao_TR_norm = confusion_matrix(d["Y"], TR_CV_norm)

linharelatorio_TR_norm = {
    'Modelo': 'Árvore de Decisão',
    'Accuracy': relatorioTR_norm['accuracy'],
    'Precision': relatorioTR_norm['1']['precision'],
    'Recall': relatorioTR_norm['1']['recall'],
    'F1-Score': relatorioTR_norm['1']['f1-score']
}

tabelaTree_CVNorm = PrettyTable()
tabelaTree_CVNorm.field_names = linharelatorio_TR_norm.keys()
tabelaTree_CVNorm.add_row(linharelatorio_TR_norm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrixconfusao_TR_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Árvore de Decisão')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Árvore de Decisão:")
print(tabelaTree_CVNorm)
# Out:
# Relatório de Classificação - Árvore de Decisão:
# +-------------------+--------------------+--------------------+--------------------+--------------------+
# |       Modelo      |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +-------------------+--------------------+--------------------+--------------------+--------------------+
# | Árvore de Decisão | 0.7940717628705148 | 0.8668989547038327 | 0.8585231193926847 | 0.8626907073509016 |
# +-------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Random Forest:

# %%
RFclassifier_cv = RandomForestClassifier()

previsoesCV_RFnorm = cross_val_predict(RFclassifier_cv, atributos, d["Y"], cv=5)

relatorioCV_RFnorm = classification_report(d["Y"], previsoesCV_RFnorm, output_dict=True)
matrix_confusaoCV_RFnorm = confusion_matrix(d["Y"], previsoesCV_RFnorm)

linha_relatorioCV_RFnorm = {
    'Modelo': 'Random Forest',
    'Accuracy': relatorioCV_RFnorm['accuracy'],
    'Precision': relatorioCV_RFnorm['1']['precision'],
    'Recall': relatorioCV_RFnorm['1']['recall'],
    'F1-Score': relatorioCV_RFnorm['1']['f1-score']
}

tabelaCV_RFnorm = PrettyTable()
tabelaCV_RFnorm.field_names = linha_relatorioCV_RFnorm.keys()
tabelaCV_RFnorm.add_row(linha_relatorioCV_RFnorm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusaoCV_RFnorm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Random Forest')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Random Forest:")
print(tabelaCV_RFnorm)
# Out:
# Relatório de Classificação - Random Forest:
# +---------------+-------------------+--------------------+--------------------+------------------+
# |     Modelo    |      Accuracy     |     Precision      |       Recall       |     F1-Score     |
# +---------------+-------------------+--------------------+--------------------+------------------+
# | Random Forest | 0.860114404576183 | 0.8757961783439491 | 0.9489302967563837 | 0.91089764822789 |
# +---------------+-------------------+--------------------+--------------------+------------------+

# %% [markdown]
# #### Naive Bayes:

# %%
NB_CV_Norm = GaussianNB()

previsoes_NB_CV_norm = cross_val_predict(NB_CV_Norm, atributos, d["Y"], cv=5)

relatorio_NB_CV_norm = classification_report(d["Y"], previsoes_NB_CV_norm, output_dict=True)
matrix_confusao_NB_CV_norm = confusion_matrix(d["Y"], previsoes_NB_CV_norm)

linharelatorio_NB_CVnorm = {
    'Modelo': 'Naive Bayes',
    'Accuracy': relatorio_NB_CV_norm['accuracy'],
    'Precision': relatorio_NB_CV_norm['1']['precision'],
    'Recall': relatorio_NB_CV_norm['1']['recall'],
    'F1-Score': relatorio_NB_CV_norm['1']['f1-score']
}

tabelaNB_CV_Norm = PrettyTable()
tabelaNB_CV_Norm.field_names = linharelatorio_NB_CVnorm.keys()
tabelaNB_CV_Norm.add_row(linharelatorio_NB_CVnorm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_NB_CV_norm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Naive Bayes')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Naive Bayes:")
print(tabelaNB_CV_Norm)
# Out:
# Relatório de Classificação - Naive Bayes:
# +-------------+--------------------+--------------------+--------------------+-------------------+
# |    Modelo   |      Accuracy      |     Precision      |       Recall       |      F1-Score     |
# +-------------+--------------------+--------------------+--------------------+-------------------+
# | Naive Bayes | 0.7535101404056163 | 0.8776142525174283 | 0.7819185645272602 | 0.827007299270073 |
# +-------------+--------------------+--------------------+--------------------+-------------------+

# %% [markdown]
# #### SVC - Support Vector Classification:

# %%
SVCclassifierCV_norm = SVC()

previsoesCV_SVCnorm = cross_val_predict(SVCclassifierCV_norm, xPca, d["Y"], cv=5)

relatorioCV_SVCnorm = classification_report(d["Y"], previsoesCV_SVCnorm, output_dict=True)
matrix_confusaoCV_SVCnorm = confusion_matrix(d["Y"], previsoesCV_SVCnorm)

linha_relatorioCV_SVCnorm = {
    'Modelo': 'Support Vector Classifier (SVC)',
    'Accuracy': relatorioCV_SVCnorm['accuracy'],
    'Precision': relatorioCV_SVCnorm['1']['precision'],
    'Recall': relatorioCV_SVCnorm['1']['recall'],
    'F1-Score': relatorioCV_SVCnorm['1']['f1-score']
}

tabelaCV_SVCnorm = PrettyTable()
tabelaCV_SVCnorm.field_names = linha_relatorioCV_SVCnorm.keys()
tabelaCV_SVCnorm.add_row(linha_relatorioCV_SVCnorm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusaoCV_SVCnorm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Support Vector Classifier (SVC)')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Support Vector Classifier (SVC):")
print(tabelaCV_SVCnorm)
# Out:
# Relatório de Classificação - Support Vector Classifier (SVC):
# +---------------------------------+--------------------+--------------------+--------------------+--------------------+
# |              Modelo             |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------------------------+--------------------+--------------------+--------------------+--------------------+
# | Support Vector Classifier (SVC) | 0.8543941757670307 | 0.8655409631019387 | 0.9551414768806074 | 0.9081364829396326 |
# +---------------------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Aplicação de Modelos Supervisionados ao Processo 2:

# %% [markdown]
# #### Logistic Regression:

# %%
RL = LogisticRegression(max_iter=1000)

RL.fit(X_train, y_train)

previsoes = RL.predict(X_test)

relatorio = classification_report(y_test, previsoes, output_dict=True)
matrix_confusao = confusion_matrix(y_test, previsoes)

linha_relatorio = {
    'Modelo': 'Regressão Logística',
    'Accuracy': relatorio['accuracy'],
    'Precision': relatorio['1']['precision'],
    'Recall': relatorio['1']['recall'],
    'F1-Score': relatorio['1']['f1-score']
}

tabela = PrettyTable()
tabela.field_names = linha_relatorio.keys()
tabela.add_row(linha_relatorio.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Regressão Logística')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação:")
print(tabela)
# Out:
# Relatório de Classificação:
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# |        Modelo       |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------------+--------------------+--------------------+--------------------+--------------------+
# | Regressão Logística | 0.8336221837088388 | 0.8346774193548387 | 0.9672897196261683 | 0.8961038961038962 |
# +---------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Decision Tree:

# %%
tree_classifier = DecisionTreeClassifier()

tree_classifier.fit(X_train, y_train)

previsoes_tree = tree_classifier.predict(X_test)

relatorio_tree = classification_report(y_test, previsoes_tree, output_dict=True)
matrix_confusao_tree = confusion_matrix(y_test, previsoes_tree)

linha_relatorio_tree = {
    'Modelo': 'Decision Tree',
    'Accuracy': relatorio_tree['accuracy'],
    'Precision': relatorio_tree['1']['precision'],
    'Recall': relatorio_tree['1']['recall'],
    'F1-Score': relatorio_tree['1']['f1-score']
}

tabelaTree = PrettyTable()
tabelaTree.field_names = linha_relatorio_tree.keys()
tabelaTree.add_row(linha_relatorio_tree.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_tree, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Árvore de Decisão')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Árvore de Decisão:")
print(tabelaTree)
# Out:
# Relatório de Classificação - Árvore de Decisão:
# +---------------+--------------------+--------------------+--------------------+--------------------+
# |     Modelo    |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------+--------------------+--------------------+--------------------+--------------------+
# | Decision Tree | 0.8076256499133448 | 0.8694638694638694 | 0.8714953271028038 | 0.8704784130688448 |
# +---------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Random Forest:

# %%
forest_classifier = RandomForestClassifier()

forest_classifier.fit(X_train, y_train)

previsoes_forest = forest_classifier.predict(X_test)

relatorio_forest = classification_report(y_test, previsoes_forest, output_dict=True)
matrix_confusao_forest = confusion_matrix(y_test, previsoes_forest)

linha_relatorio_forest = {
    'Modelo': 'Random Forest',
    'Accuracy': relatorio_forest['accuracy'],
    'Precision': relatorio_forest['1']['precision'],
    'Recall': relatorio_forest['1']['recall'],
    'F1-Score': relatorio_forest['1']['f1-score']
}

tabelaForest = PrettyTable()
tabelaForest.field_names = linha_relatorio_forest.keys()
tabelaForest.add_row(linha_relatorio_forest.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_forest, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Random Forest')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Random Forest:")
print(tabelaForest)
# Out:
# Relatório de Classificação - Random Forest:
# +---------------+-------------------+-------------------+--------------------+--------------------+
# |     Modelo    |      Accuracy     |     Precision     |       Recall       |      F1-Score      |
# +---------------+-------------------+-------------------+--------------------+--------------------+
# | Random Forest | 0.854419410745234 | 0.869098712446352 | 0.9462616822429907 | 0.9060402684563759 |
# +---------------+-------------------+-------------------+--------------------+--------------------+

# %% [markdown]
# #### Naive Bayes:

# %%
nb_classifier = GaussianNB()

nb_classifier.fit(X_train, y_train)

previsoes_nb = nb_classifier.predict(X_test)

relatorio_nb = classification_report(y_test, previsoes_nb, output_dict=True)
matrix_confusao_nb = confusion_matrix(y_test, previsoes_nb)

linha_relatorio_nb = {
    'Modelo': 'Naive Bayes',
    'Accuracy': relatorio_nb['accuracy'],
    'Precision': relatorio_nb['1']['precision'],
    'Recall': relatorio_nb['1']['recall'],
    'F1-Score': relatorio_nb['1']['f1-score']
}

tabelaNB = PrettyTable()
tabelaNB.field_names = linha_relatorio_nb.keys()
tabelaNB.add_row(linha_relatorio_nb.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_nb, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Naive Bayes')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Naive Bayes:")
print(tabelaNB)
# Out:
# Relatório de Classificação - Naive Bayes:
# +-------------+--------------------+--------------------+--------------------+--------------------+
# |    Modelo   |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +-------------+--------------------+--------------------+--------------------+--------------------+
# | Naive Bayes | 0.8093587521663779 | 0.8382978723404255 | 0.9205607476635514 | 0.8775055679287305 |
# +-------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### SVC - Support Vector Classification:

# %%
svm_classifier = SVC()

svm_classifier.fit(X_train, y_train)

previsoes_svm = svm_classifier.predict(X_test)

relatorio_svm = classification_report(y_test, previsoes_svm, output_dict=True)
matrix_confusao_svm = confusion_matrix(y_test, previsoes_svm)

linha_relatorio_svm = {
    'Modelo': 'SVM',
    'Accuracy': relatorio_svm['accuracy'],
    'Precision': relatorio_svm['1']['precision'],
    'Recall': relatorio_svm['1']['recall'],
    'F1-Score': relatorio_svm['1']['f1-score']
}

tabelaSVM = PrettyTable()
tabelaSVM.field_names = linha_relatorio_svm.keys()
tabelaSVM.add_row(linha_relatorio_svm.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_svm, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - SVM')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - SVM:")
print(tabelaSVM)
# Out:
# Relatório de Classificação - SVM:
# +--------+--------------------+--------------------+--------------------+--------------------+
# | Modelo |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +--------+--------------------+--------------------+--------------------+--------------------+
# |  SVM   | 0.8440207972270364 | 0.8550420168067226 | 0.9509345794392523 | 0.9004424778761061 |
# +--------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Aplicação de Modelos Supervisionados ao Processo 2, com a particição de dados através do Cross-Validation:

# %% [markdown]
# #### Logistic Regression:

# %%
modeloRL = LogisticRegression(max_iter=1000)
modeloRL.fit(X_train, y_train)

previsoes_cv = cross_val_predict(modeloRL, xPca, d["Y"], cv=5)

relatorio_cv = classification_report(d["Y"], previsoes_cv, output_dict=True)
matrix_confusao_cv = confusion_matrix(d["Y"], previsoes_cv)

linha_relatorio_cv = {
    'Modelo': 'Regressão Logística',
    'Accuracy': relatorio_cv['accuracy'],
    'Precision': relatorio_cv['1']['precision'],
    'Recall': relatorio_cv['1']['recall'],
    'F1-Score': relatorio_cv['1']['f1-score']
}

tabela_cv = PrettyTable()
tabela_cv.field_names = linha_relatorio_cv.keys()
tabela_cv.add_row(linha_relatorio_cv.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_cv, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Regressão Logística')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação:")
print(tabela_cv)
# Out:
# Relatório de Classificação:
# +---------------------+-------------------+--------------------+--------------------+-------------------+
# |        Modelo       |      Accuracy     |     Precision      |       Recall       |      F1-Score     |
# +---------------------+-------------------+--------------------+--------------------+-------------------+
# | Regressão Logística | 0.843473738949558 | 0.8551980198019802 | 0.9537612146307799 | 0.901794453507341 |
# +---------------------+-------------------+--------------------+--------------------+-------------------+

# %% [markdown]
# #### Decision Tree:

# %%
tree_classifier_cv = DecisionTreeClassifier()

previsoes_tree_cv = cross_val_predict(tree_classifier_cv, xPca, d["Y"], cv=5)

relatorio_tree_cv = classification_report(d["Y"], previsoes_tree_cv, output_dict=True)
matrix_confusao_tree_cv = confusion_matrix(d["Y"], previsoes_tree_cv)

linha_relatorio_tree_cv = {
    'Modelo': 'Árvore de Decisão',
    'Accuracy': relatorio_tree_cv['accuracy'],
    'Precision': relatorio_tree_cv['1']['precision'],
    'Recall': relatorio_tree_cv['1']['recall'],
    'F1-Score': relatorio_tree_cv['1']['f1-score']
}

tabelaTree_cv = PrettyTable()
tabelaTree_cv.field_names = linha_relatorio_tree_cv.keys()
tabelaTree_cv.add_row(linha_relatorio_tree_cv.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_tree_cv, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Árvore de Decisão')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Árvore de Decisão:")
print(tabelaTree_cv)
# Out:
# Relatório de Classificação - Árvore de Decisão:
# +-------------------+--------------------+--------------------+--------------------+--------------------+
# |       Modelo      |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +-------------------+--------------------+--------------------+--------------------+--------------------+
# | Árvore de Decisão | 0.7826313052522101 | 0.8533241946538725 | 0.8592132505175983 | 0.8562585969738651 |
# +-------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Random Forest:

# %%
forest_classifier_cv = RandomForestClassifier()

previsoes_forest_cv = cross_val_predict(forest_classifier_cv, xPca, d["Y"], cv=5)

relatorio_forest_cv = classification_report(d["Y"], previsoes_forest_cv, output_dict=True)
matrix_confusao_forest_cv = confusion_matrix(d["Y"], previsoes_forest_cv)

linha_relatorio_forest_cv = {
    'Modelo': 'Random Forest',
    'Accuracy': relatorio_forest_cv['accuracy'],
    'Precision': relatorio_forest_cv['1']['precision'],
    'Recall': relatorio_forest_cv['1']['recall'],
    'F1-Score': relatorio_forest_cv['1']['f1-score']
}

tabelaForest_cv = PrettyTable()
tabelaForest_cv.field_names = linha_relatorio_forest_cv.keys()
tabelaForest_cv.add_row(linha_relatorio_forest_cv.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_forest_cv, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Random Forest')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Random Forest:")
print(tabelaForest_cv)
# Out:
# Relatório de Classificação - Random Forest:
# +---------------+--------------------+--------------------+--------------------+--------------------+
# |     Modelo    |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------+--------------------+--------------------+--------------------+--------------------+
# | Random Forest | 0.8507540301612064 | 0.8710089399744572 | 0.9413388543823327 | 0.9048092868988391 |
# +---------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Naive Bayes:

# %%
nb_classifier_cv = GaussianNB()

previsoes_nb_cv = cross_val_predict(nb_classifier_cv, xPca, d["Y"], cv=5)

relatorio_nb_cv = classification_report(d["Y"], previsoes_nb_cv, output_dict=True)
matrix_confusao_nb_cv = confusion_matrix(d["Y"], previsoes_nb_cv)

linha_relatorio_nb_cv = {
    'Modelo': 'Naive Bayes',
    'Divisão de Dados': 'CV',
    'Accuracy': relatorio_nb_cv['accuracy'],
    'Precision': relatorio_nb_cv['1']['precision'],
    'Recall': relatorio_nb_cv['1']['recall'],
    'F1-Score': relatorio_nb_cv['1']['f1-score']
}

tabelaNB_cv = PrettyTable()
tabelaNB_cv.field_names = linha_relatorio_nb_cv.keys()
tabelaNB_cv.add_row(linha_relatorio_nb_cv.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_nb_cv, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Naive Bayes')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Naive Bayes:")
print(tabelaNB_cv)
# Out:
# Relatório de Classificação - Naive Bayes:
# +-------------+------------------+-------------------+--------------------+--------------------+--------------------+
# |    Modelo   | Divisão de Dados |      Accuracy     |     Precision      |       Recall       |      F1-Score      |
# +-------------+------------------+-------------------+--------------------+--------------------+--------------------+
# | Naive Bayes |        CV        | 0.797191887675507 | 0.8427184466019417 | 0.8985507246376812 | 0.8697394789579159 |
# +-------------+------------------+-------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### SVC - Support Vector Classification:

# %%
svc_classifier_cv = SVC()

previsoes_svc_cv = cross_val_predict(svc_classifier_cv, xPca, d["Y"], cv=5)

relatorio_svc_cv = classification_report(d["Y"], previsoes_svc_cv, output_dict=True)
matrix_confusao_svc_cv = confusion_matrix(d["Y"], previsoes_svc_cv)

linha_relatorio_svc_cv = {
    'Modelo': 'Support Vector Classifier (SVC)',
    'Divisão de Dados': 'CV',
    'Accuracy': relatorio_svc_cv['accuracy'],
    'Precision': relatorio_svc_cv['1']['precision'],
    'Recall': relatorio_svc_cv['1']['recall'],
    'F1-Score': relatorio_svc_cv['1']['f1-score']
}

tabelaSVC_cv = PrettyTable()
tabelaSVC_cv.field_names = linha_relatorio_svc_cv.keys()
tabelaSVC_cv.add_row(linha_relatorio_svc_cv.values())

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_svc_cv, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Support Vector Classifier (SVC)')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

print("\nRelatório de Classificação - Support Vector Classifier (SVC):")
print(tabelaSVC_cv)
# Out:
# Relatório de Classificação - Support Vector Classifier (SVC):
# +---------------------------------+------------------+--------------------+--------------------+--------------------+--------------------+
# |              Modelo             | Divisão de Dados |      Accuracy      |     Precision      |       Recall       |      F1-Score      |
# +---------------------------------+------------------+--------------------+--------------------+--------------------+--------------------+
# | Support Vector Classifier (SVC) |        CV        | 0.8543941757670307 | 0.8655409631019387 | 0.9551414768806074 | 0.9081364829396326 |
# +---------------------------------+------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# #### Tabela de Resultados:
#
# A tabela de resultados apresenta uma visão abrangente e comparativa do desempenho dos diversos modelos utilizados no estudo. Nesta tabela, são sumarizadas as métricas calculadas que permitem visualiar a capacidade de previsão e eficácia de cada modelo na classificação. As métricas incluídas são, tal como referido previamente, a accuracy, a precision, o recall e F1-Score.
#
# A accuracy destaca a proporção de previsões corretas em relação ao total de observações, enquanto a precision avalia a capacidade das previsões positivas. O recall, por sua vez, dita a capacidade do modelo em identificar corretamente todas as instâncias positivas, sendo especialmente relevante em situações onde falsos negativos são críticos. O F1-Score, consiste  numa métrica que combina a precision e o recall, proporcionando uma medida balanceada entre esses dois aspectos, sendo útil quando se procura um equilíbrio entre a identificação correta de instâncias positivas e a minimização de falsos positivos e negativos.
#
# Essa tabela permite uma análise comparativa das performances dos modelos em diferentes cenários, auxiliando na identificação daquele que melhor atende aos objetivos específicos do estudo.

# %%
data = [
    ["Process 1", "SD", "Logistic Regression", round(relatorioRL_norm['accuracy'],3), round(relatorioRL_norm['1']['precision'],3), round(relatorioRL_norm['1']['recall'],3), round(relatorioRL_norm['1']['f1-score'],3)],
    ["Process 1", "SD", "Decision Tree",  round(relatorio_tree_RL['accuracy'],3), round(relatorio_tree_RL['1']['precision'],3), round(relatorio_tree_RL['1']['recall'],3), round(relatorio_tree_RL['1']['f1-score'],3) ],
    ["Process 1", "SD", "Random Forest",  round(relatorio_forest_norm['accuracy'],3), round(relatorio_forest_norm['1']['precision'],3), round(relatorio_forest_norm['1']['recall'],3), round(relatorio_forest_norm['1']['f1-score'],3) ],
    ["Process 1", "SD", "Naive Bayes",  round(relatorio_NB_norm['accuracy'],3), round(relatorio_NB_norm['1']['precision'],3), round(relatorio_NB_norm['1']['recall'],3), round(relatorio_NB_norm['1']['f1-score'],3) ],
    ["Process 1", "SD", "SVC",  round(relatorio_SVC_norm['accuracy'],3), round(relatorio_SVC_norm['1']['precision'],3), round(relatorio_SVC_norm['1']['recall'],3), round(relatorio_SVC_norm['1']['f1-score'],3) ],
    ["----------","----------","----------","----------","----------","----------","----------"],
    ["Process 1", "CV", "Logistic Regression",  round(relatorio_cv['accuracy'],3), round(relatorio_cv['1']['precision'],3), round(relatorio_cv['1']['recall'],3), round(relatorio_cv['1']['f1-score'],3) ],
    ["Process 1", "CV", "Decision Tree",  round(relatorioTR_norm['accuracy'],3), round(relatorioTR_norm['1']['precision'],3), round(relatorioTR_norm['1']['recall'],3), round(relatorioTR_norm['1']['f1-score'],3) ],
    ["Process 1", "CV", "Random Forest",  round(relatorioCV_RFnorm['accuracy'],3), round(relatorioCV_RFnorm['1']['precision'],3), round(relatorioCV_RFnorm['1']['recall'],3), round(relatorioCV_RFnorm['1']['f1-score'],3) ],
    ["Process 1", "CV", "Naive Bayes",  round(relatorio_NB_CV_norm['accuracy'],3), round(relatorio_NB_CV_norm['1']['precision'],3), round(relatorio_NB_CV_norm['1']['recall'],3), round(relatorio_NB_CV_norm['1']['f1-score'],3) ],
    ["Process 1", "CV", "SVC",  round(relatorioCV_SVCnorm['accuracy'],3), round(relatorioCV_SVCnorm['1']['precision'],3), round(relatorioCV_SVCnorm['1']['recall'],3), round(relatorioCV_SVCnorm['1']['f1-score'],3) ],
    ["----------","----------","----------","----------","----------","----------","----------"],
    ["Process 2", "SD", "Logistic Regression",  round(relatorio['accuracy'],3), round(relatorio['1']['precision'],3), round(relatorio['1']['recall'],3), round(relatorio['1']['f1-score'],3) ],
    ["Process 2", "SD", "Decision Tree",  round(relatorio_tree['accuracy'],3), round(relatorio_tree['1']['precision'],3), round(relatorio_tree['1']['recall'],3), round(relatorio_tree['1']['f1-score'],3) ],
    ["Process 2", "SD", "Random Forest",  round(relatorio_forest['accuracy'],3), round(relatorio_forest['1']['precision'],3), round(relatorio_forest['1']['recall'],3), round(relatorio_forest['1']['f1-score'],3) ],
    ["Process 2", "SD", "Naive Bayes",  round(relatorio_nb['accuracy'],3), round(relatorio_nb['1']['precision'],3), round(relatorio_nb['1']['recall'],3), round(relatorio_nb['1']['f1-score'],3) ],
    ["Process 2", "SD", "SVC",  round(relatorio_svm['accuracy'],3), round(relatorio_svm['1']['precision'],3), round(relatorio_svm['1']['recall'],3), round(relatorio_svm['1']['f1-score'],3) ],
    ["----------","----------","----------","----------","----------","----------","----------"],
    ["Process 2", "CV", "Logistic Regression",  round(relatorio_cv['accuracy'],3), round(relatorio_cv['1']['precision'],3), round(relatorio_cv['1']['recall'],3), round(relatorio_cv['1']['f1-score'],3) ],
    ["Process 2", "CV", "Decision Tree",  round(relatorio_tree_cv['accuracy'],3), round(relatorio_tree_cv['1']['precision'],3), round(relatorio_tree_cv['1']['recall'],3), round(relatorio_tree_cv['1']['f1-score'],3) ],
    ["Process 2", "CV", "Random Forest",  round( relatorio_forest_cv['accuracy'],3), round( relatorio_forest_cv['1']['precision'],3), round( relatorio_forest_cv['1']['recall'],3), round( relatorio_forest_cv['1']['f1-score'],3) ],
    ["Process 2", "CV", "Naive Bayes",  round(relatorio_nb_cv['accuracy'],3), round(relatorio_nb_cv['1']['precision'],3), round(relatorio_nb_cv['1']['recall'],3), round(relatorio_nb_cv['1']['f1-score'],3) ],
    ["Process 2", "CV", "SVC",  round(relatorio_svc_cv['accuracy'],3), round(relatorio_svc_cv['1']['precision'],3), round(relatorio_svc_cv['1']['recall'],3), round(relatorio_svc_cv['1']['f1-score'],3) ],  
]

columns = ["Processo", "Divisão de Dados", "Modelo", "Accuracy","Precision", "Recall", "F1-Score" ]

table = PrettyTable(columns)

for row in data:
    table.add_row(row)

print(table)
# Out:
# +------------+------------------+---------------------+------------+------------+------------+------------+
# |  Processo  | Divisão de Dados |        Modelo       |  Accuracy  | Precision  |   Recall   |  F1-Score  |
# +------------+------------------+---------------------+------------+------------+------------+------------+
# | Process 1  |        SD        | Logistic Regression |   0.841    |   0.848    |   0.961    |   0.901    |
# | Process 1  |        SD        |    Decision Tree    |   0.821    |   0.876    |    0.89    |   0.883    |
# | Process 1  |        SD        |    Random Forest    |   0.854    |   0.873    |   0.945    |   0.907    |
# | Process 1  |        SD        |     Naive Bayes     |   0.818    |   0.862    |   0.903    |   0.882    |
# | Process 1  |        SD        |         SVC         |   0.832    |   0.842    |   0.956    |   0.896    |
# | ---------- |    ----------    |      ----------     | ---------- | ---------- | ---------- | ---------- |
# ...

# %% [markdown]
# #### Ensemble Model:
#
# Ideia central da construção de ensemble models reside na obtenção de respostas a situações novas, a partir da combinação das respostas de diferentes modelos. De facto, a construção de ensemble models permite combinar as previsões de vários modelos individuais de modo a obter um desempenho otimizado, relativamente do que o desempenho individual. Assim, usando os diferentes modelos desenvolvidos posibilita o aprimoramento da precisão e da robustez dos resultados.
#
# #### Voting Classifier:
#
# A utilização do Voting Classifier, na construção de um ensemble model, permite combinar vários modelos de aprendizagem supervisionada para tomar decisões por votação. Nos modelos desenvolvidos foi considerada a "hard voting", na medida em que as previsões de cada modelo são consideradas no ensemble model, e a classe que recebe a maioria dos votos, dos modelos individuais, é selecionada como a previsão final.
#
# #### Aplicação do Voting Classifier ao Processo 1 com partição de Dados Split Data:

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import VotingClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from prettytable import PrettyTable

def create_voting_classifier(models):
    voting_models = [(name, model) for name, model in models]
    voting_clf = VotingClassifier(estimators=voting_models, voting='soft')
    return voting_clf

model_list = [
    ('SVC', SVC_norm),
    ('RandomForest', RFC_norm),
    ('NaiveBayes', NB_norm),
]

voting_classifier = create_voting_classifier(model_list)

voting_classifier.fit(X_train_norm, y_train_norm)
previsoes_voting = voting_classifier.predict(X_test_norm)

relatorio_voting = classification_report(y_test_norm, previsoes_voting, output_dict=True)


linha_relatorio_Ensemble = {
    'Modelo': 'Voting Classifier',
    'Divisão de Dados': 'SD',
    'Accuracy': str(relatorio_voting['accuracy']),
    'Precision': str(relatorio_voting['1']['precision']),
    'Recall': str(relatorio_voting['1']['recall']),
    'F1-Score': str(relatorio_voting['1']['f1-score'])
}

tabela_ensemble = PrettyTable()
tabela_ensemble.field_names = linha_relatorio_Ensemble.keys()
tabela_ensemble.add_row(linha_relatorio_Ensemble.values())

print("\nTabela do Relatório:")
print(tabela_ensemble)

matrix_confusao_voting = confusion_matrix(y_test_norm, previsoes_voting)

plt.figure(figsize=(2, 2))
sns.heatmap(matrix_confusao_voting, annot=True, fmt='d', cmap='Blues', cbar=False, linewidths=0.5)
plt.title('Matriz de Confusão - Voting Classifier')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()
# Out:
# Tabela do Relatório:
# +-------------------+------------------+--------------------+-------------------+--------------------+--------------------+
# |       Modelo      | Divisão de Dados |      Accuracy      |     Precision     |       Recall       |      F1-Score      |
# +-------------------+------------------+--------------------+-------------------+--------------------+--------------------+
# | Voting Classifier |        SD        | 0.8440207972270364 | 0.864693446088795 | 0.9402298850574713 | 0.9008810572687225 |
# +-------------------+------------------+--------------------+-------------------+--------------------+--------------------+

# %% [markdown]
# O código anterior permite a criação de um ensemble model, combinando 3 modelos diferentes.
#
# Comparando o desempenho do ensemble model com os modelos individuais constata-se que este obteve uma accuracy média de 84%, valor próximo ao dos modelos inividuais mais fortes. Devido ao modelo de Naive Bayes apresentar uma menor accuracy média, a sua incorporação no ensemble model poderá ter contribuído para piorar a robustez geral.

# %% [markdown]
# #### Avaliação dos Resultados:
#
# Na análise da tabela que combina os resultados obtidos nos diferentes processos e modelos, podemos destacar algumas observações importantes:
#
# 1. **Melhor Resultado:**
#    - Não há um modelo que se destaque consistentemente como o melhor em todas as métricas. Por exemplo, o modelo Random Forest no Processo 1 com divisão de dados utilizando validação cruzada (CV) atinge uma precision de 0.876 e um recall de 0.949, sugerindo um bom equilíbrio entre accuracy e capacidade de identificar positivos.
#
# 2. **Atenção aos Falsos Positivos (Precision) e Falsos Negativos (Recall):**
#    - No contexto médico, é crucial prestar atenção aos Falsos Positivos (FP) e Falsos Negativos (FN). O modelo Naive Bayes no Processo 1, com validação cruzada (CV), apresenta um recall de 0.782, indicando que ele pode não ser ideal para identificar positivos, o que poderia resultar em casos não detectados.
#
# 3. **Desempenho do Processo 2 (PCA):**
#    - Observa-se que o Processo 2, onde o conjunto de dados foi reduzido usando PCA, apresenta um desempenho semelhante ao do conjunto de dados original normalizado. Por exemplo, o modelo Support Vector Classifier (SVC) no Processo 2 (CV) tem uma precision de 0.866 e um recall de 0.955, destacando a eficiência do modelo em lidar com um conjunto de dados reduzido. Isto é benéfico dado que exije processamento de menos dados e consequentemente, menor sobrecarga à máquina.
#
# 4. **Cross-Validation (CV):**
#    - A aplicação de validação cruzada não resultou num aumento significativo no desempenho do modelo em alguns casos. O modelo Decision Tree no Processo 1 (CV) tem uma accuracy de 0.794, sugerindo que a validação cruzada pode não ter impacto substancial em todos os cenários.
#
# 5. **Ensemble Model:**
#    - A escolha de um ensemble model pode ser uma escolha apropriada, comparativamente aos restantes modelos avaliados, visto que proporciona um equilíbrio entre a accuracy e a robustez dos resultados. Apesar de este modelo não mostrar o melhor desempenho, a construção do emsemble modelo permite a combinação das respostas de cada modelo individual, possibilitando, assim, a obtenção de respostas para diferentes, ou até, novas situações, pelo que, continua a ser uma escolha a ter em consideração.
#
# Em resumo, ao considerar modelos específicos, como o Random Forest no Processo 1 e o Naive Bayes no Processo 1 (CV), estes podem fornecer insights mais concretos sobre o desempenho e as considerações específicas relacionadas a Falsos Positivos e Falsos Negativos. Essas observações são fundamentais ao escolher um modelo para a área médica, onde a precisão e a capacidade de identificar corretamente condições são de extrema importância.
